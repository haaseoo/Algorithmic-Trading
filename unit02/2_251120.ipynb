# %%
naver = 601000

# %%
naver
# Out:
# 601000

# %%
naver * 10
# Out:
# 6010000

# %%
monday_end_price = 10000-(10000*0.3)

# %%
tuesday_end_price = monday_end_price - (monday_end_price * 0.3)

# %%
tuesday_end_price
# Out:
# 4900.0

# %%
x = 100

# %%
id(x)
# Out:
# 4345035544

# %%
x = 100
y = 100

# %%
id(x), id(y)
# Out:
# (4345035544, 4345035544)

# %%
x = 10000
y = 10000

# %%
id(x), id(y)
# Out:
# (4720468624, 4720469168)
