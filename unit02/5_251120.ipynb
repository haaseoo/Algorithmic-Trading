# %%
# 2-1
daum_jusik = 89000
naver_jusik = 751000
totalmine = (daum_jusik*100) + (naver_jusik*20)
totalmine
# Out:
# 23920000

# %%
# 2-2
current_daum = daum_jusik * 0.95
current_naver = naver_jusik * 0.9

totalloss = totalmine - (current_daum*100 + current_naver*20)
print(totalloss)
# Out:
# 1947000.0

# %%
daum = 89000
naver = 751000
loss = (daum*0.05*100) + (naver*0.1*20)
print(loss)
# Out:
# 1947000.0

# %%
# 2-3
F = 50
C = (current_F-32)/1.8
C
# Out:
# 10.0

# %%
# 2-4
"pizza"*10
# Out:
# 'pizzapizzapizzapizzapizzapizzapizzapizzapizzapizza'

# %%
print("pizza\n"*10)
# Out:
# pizza
# pizza
# pizza
# pizza
# pizza
# pizza
# pizza
# pizza
# pizza
# pizza

# %%
# 2-5
monday_naver = 1000000
tuesday_naver = monday_naver*0.7
wednesday_naver = tuesday_naver*0.7
print(wednesday_naver)
# Out:
# 489999.99999999994

# %%
# 2-6
print("이름: "+input()) 
print("생년월일: "+input()) 
print("주민등록번호: "+input())
# Out:
# 이름: 파이썬
# 생년월일: 2014년 12월 12일
# 주민등록번호: 20141212-162412

# %%
# 2-7 
s = 'Daum Kakao'
s = s.split(' ')[1] + ' ' + s.split(' ')[0]
s
# Out:
# 'Kakao Daum'

# %%
s = 'Daum Kakao'
s = s[5:] + " " + s[0:4]
s
# Out:
# 'Kakao Daum'

# %%
# 2-8
a = 'hello world'
a = 'hi' + a[5:]
a
# Out:
# 'hi world'

# %%
# 2-9
x = 'abcdef'
x = x[1:] + x[0]
x
# Out:
# 'bcdefa'
