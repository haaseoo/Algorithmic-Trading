# %%
# 1
for i in range(5):
  print('*', end="")
# Out:
# *****

# %%
for i in range(5):
  print('*', end='')
# Out:
# *****

# %%
# 2
for i in range(4):
  for j in range(5):
    print('*', end="")
  print(" ")
# Out:
# *****
# *****
# *****
# *****

# %%
for j in range(4):
  for i in range(5):
    print('*', end="")
  print('')
# Out:
# *****
# *****
# *****
# *****

# %%
# 3
i = 1

for i in range(1, 6):
  print('*' * i)
  i += 1
# Out:
# *
# **
# ***
# ****
# *****

# %%
for j in range(5):
  for i in range(j+1):
    print('*', end='')
  print('')
# Out:
# *
# **
# ***
# ****
# *****

# %%
for j in range(5):
  for i in range(j+1):
    print('*', end='')
  print('')
# Out:
# *
# **
# ***
# ****
# *****

# %%
# 4

for i in range(1, 6):
  for j in range(6 - i):
    print('*', end="")
  print('')
# Out:
# *****
# ****
# ***
# **
# *

# %%
for j in range(5):
  for i in range(5-j):
    print('*', end='')
  print('')
# Out:
# *****
# ****
# ***
# **
# *

# %%
# 5

for i in range(1, 6):
  for j in range(i):
    print(' '* (6-i) + '*', end='')
  print('')
# Out:
#      *
#     *    *
#    *   *   *
#   *  *  *  *
#  * * * * *

# %%
for j in range(5):
  for i in range(4-j):
    print(' ', end='')
  for i in range(j+1):
    print('*', end='')
  print('')
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
# 6

for j in range(5):
  for i in range(j):
    print(' ', end='')
  for i in range(5-j):
    print('*', end='')
  print('')
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
# 7

for j in range(9):
  for i in range(j+1):
    i += 1 
    print('*', end='')
  for i in range(9 - i):
    print(' ', end='')
  print('')
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********

# %%
for j in range(5):
  for i in range(4-j):
    print(' ', end='')
  for i in range(2*(j+1)-1):
    print('*', end='')
  print('')
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
# 8

for j in range(5):
  for i in range(j):
    print(' ', end='')
  for i in range(10-(2*(j+1)-1)):
    print('*', end='')
  print('')
# Out:
# *********
#  *******
#   *****
#    ***
#     *

# %%
for j in range(5):
  for i in range(j):
    print(' ', end='')
  for i in range(2*(5-j)-1):
    print('*', end='')
  print('')
# Out:
# *********
#  *******
#   *****
#    ***
#     *

# %%
# 9

apart = [[101, 102, 103, 104], [201, 202, 203, 204], [301, 302, 303, 304], [401, 402, 403, 404]]
arrears =[101, 203, 301, 404]

for floor in apart:
  for room in floor:
    if room in arrears:
      pass
    else:
      print('delivery,', room)
# Out:
# delivery, 102
# delivery, 103
# delivery, 104
# delivery, 201
# delivery, 202
# delivery, 204
# delivery, 302
# delivery, 303
# delivery, 304
# delivery, 401
# delivery, 402
# delivery, 403

# %%
# 9

apart = [[101, 102, 103, 104], [201, 202, 203, 204], [301, 302, 303, 304], [401, 402, 403, 404]]
arrears =[101, 203, 301, 404]

for floor in apart:
  for room in floor:
    if room in arrears:
      continue
    else:
      print('delivery,', room)
# Out:
# delivery, 102
# delivery, 103
# delivery, 104
# delivery, 201
# delivery, 202
# delivery, 204
# delivery, 302
# delivery, 303
# delivery, 304
# delivery, 401
# delivery, 402
# delivery, 403
