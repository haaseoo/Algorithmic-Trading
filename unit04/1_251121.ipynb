# %%
a = True
type(a)
# Out:
# bool

# %%
b = False
type(b)
# Out:
# bool

# %%
3 == 3
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
3 < 3
# Out:
# False

# %%
3 > 3
# Out:
# False

# %%
3<=3
# Out:
# True

# %%
3>=3
# Out:
# True

# %%
mystock = "naver"

# %%
mystock == "naver"
# Out:
# True

# %%
day1 = 10000
day2 = 13000

(day2-day1) == (day1 * 0.3)
# Out:
# True
