# %%
name = "Anhaseo"
email = "haseo@gmail.com"
addr = "seoul"

def print_business_card(name, email, addr):
  print("-------------------------")
  print("Name: %s" % name)
  print("E-mail: %s" % email)
  print("Office Address: %s" % addr)
  print("-------------------------")

# %%
print_business_card(name, email, addr)
# Out:
# -------------------------
# Name: Anhaseo
# E-mail: haseo@naver.com
# Office Address: seoul
# -------------------------

# %%
name2 = "Somyeong"
email2 = "somyeong@gmail.com"
addr2 = "Jeju"

print_business_card(name2, email2, addr2)
# Out:
# -------------------------
# Name: Somyeong
# E-mail: somyeong@gmail.com
# Office Address: Jeju
# -------------------------

# %% [markdown]
# 회원 수가 무지막지 늘어나게 된다면... 어떻게 개인 정보를 저장할 것인가?

# %%
type(3)
# Out:
# int

# %%
type(3.1)
# Out:
# float

# %%
type('3')
# Out:
# str

# %%
type(())
# Out:
# tuple

# %%
def foo():
  pass

type(foo)
# Out:
# function

# %%
class BusinessCard:
  pass

# %%
card1 = BusinessCard()
card1

# %%
class BusinessCard:
  def set_info(self, name, email, addr):
    self.name = name
    self.email = email
    self.addr = addr

# %%
member1 = BusinessCard()
member1

# %%
member1.set_info("Yuna Kim", "yunakim@naver.com", "Seoul")

# %%
member1.name
# Out:
# 'Yuna Kim'

# %%
member1.email
# Out:
# 'yunakim@naver.com'

# %%
member1.addr
# Out:
# 'Seoul'

# %%
member2 = BusinessCard()
member2.set_info("Sarang Lee", "sarang@naver.com", "Kyunggi")

# %%
member2.name
# Out:
# 'Sarang Lee'

# %%
member2.email
# Out:
# 'sarang@naver.com'

# %%
member2.addr
# Out:
# 'Kyunggi'

# %%
class BusinessCard:
  def set_info(self, name, email, addr):
    self.name = name
    self.email = email
    self.addr = addr
  def print_info(self):
    print("----------------------------")
    print("Name: ", self.name)
    print("E-mail: ", self.email)
    print("Address: ", self.addr)
    print("----------------------------")

# %%
member1 = BusinessCard()
member1.set_info("Yunakim", "yuna.kim@naver.com", "seoul")

# %%
member1.print_info()
# Out:
# ----------------------------
# Name:  Yunakim
# E-mail:  yuna.kim@naver.com
# Address:  seoul
# ----------------------------
