# %%
interest1 = "삼성전자"
interest2 = "LG전자"
interest3 = "네이버"

# %%
interest = ["삼성", "LG", "NAVER"]

# %%
interest[0]
# Out:
# '삼성'

# %%
interest[1]
# Out:
# 'LG'

# %%
interest[2]
# Out:
# 'NAVER'

# %%
daishin = [9130, 9150, 9150, 9300, 9400]

# %%
kospi_top10 = ["삼성전자", "SK 하이닉스", "현대차", "한국전력", "아모레퍼시픽", "제일모직", "삼성전자우", "삼성생명", "네이버", "현대모비스"]

# %%
print("시가총액 5위: ", kospi_top10[4])
# Out:
# 시가총액 5위:  아모레퍼시픽

# %%
kospi_top5 = kospi_top10[0:5]

# %%
kospi_top5
# Out:
# ['삼성전자', 'SK 하이닉스', '현대차', '한국전력', '아모레퍼시픽']

# %%
kospi_top10[5:9]
# Out:
# ['제일모직', '삼성전자우', '삼성생명', '네이버']

# %%
kospi_top10[5:10]
# Out:
# ['제일모직', '삼성전자우', '삼성생명', '네이버', '현대모비스']

# %%
kospi_top10[5:-1]
# Out:
# ['제일모직', '삼성전자우', '삼성생명', '네이버']

# %%
kospi_top10.append('SK 텔레콤')

# %%
kospi_top10
# Out:
# ['삼성전자',
#  'SK 하이닉스',
#  '현대차',
#  '한국전력',
#  '아모레퍼시픽',
#  '제일모직',
#  '삼성전자우',
#  '삼성생명',
#  '네이버',
#  '현대모비스',
#  'SK 텔레콤']

# %%
kospi_top10 = ["삼성전자", "SK 하이닉스", "현대차", "한국전력", "아모레퍼시픽", "제일모직", "삼성전자우", "삼성생명", "네이버", "현대모비스"]

# %%
kospi_top10.insert(3, "SK 텔레콤")

# %%
kospi_top10
# Out:
# ['삼성전자',
#  'SK 하이닉스',
#  '현대차',
#  'SK 텔레콤',
#  '한국전력',
#  '아모레퍼시픽',
#  '제일모직',
#  '삼성전자우',
#  '삼성생명',
#  '네이버',
#  '현대모비스']

# %%
len(kospi_top10)
# Out:
# 11

# %%
del kospi_top10[-1]

# %%
kospi_top10
# Out:
# ['삼성전자',
#  'SK 하이닉스',
#  '현대차',
#  'SK 텔레콤',
#  '한국전력',
#  '아모레퍼시픽',
#  '제일모직',
#  '삼성전자우',
#  '삼성생명',
#  '네이버']
