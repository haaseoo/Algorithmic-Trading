# %%
cur_price = {}

# %%
type(cur_price)
# Out:
# dict

# %%
cur_price['Daeshin'] = 30000

# %%
cur_price
# Out:
# {'Daeshin': 30000}

# %%
cur_price["Daum KAKAO"] = 80000

# %%
len(cur_price)
# Out:
# 2

# %%
cur_price['Daeshin']
# Out:
# 30000

# %%
cur_price
# Out:
# {'Daeshin': 30000, 'Daum KAKAO': 80000}

# %%
cur_price['naver'] = 800000

# %%
del cur_price['Daeshin']

# %%
cur_price
# Out:
# {'Daum KAKAO': 80000, 'naver': 800000}

# %%
dic = {"Daum KAKAO": 80000, "NAVER": 800000, "NVdia": 1000000}

# %%
dic.keys()
# Out:
# dict_keys(['Daum KAKAO', 'NAVER', 'NVdia'])

# %%
list(dic.keys())
# Out:
# ['Daum KAKAO', 'NAVER', 'NVdia']

# %%
stock_list = list(dic.keys())
stock_list
# Out:
# ['Daum KAKAO', 'NAVER', 'NVdia']

# %%
price_list = list(dic.values())
price_list
# Out:
# [80000, 800000, 1000000]

# %%
'Samsung' in dic.keys()
# Out:
# False

# %%
'NAVER' in dic
# Out:
# True

# %%
dic['NAVER']
# Out:
# 800000
