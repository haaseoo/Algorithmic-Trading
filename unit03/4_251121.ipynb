# %%
# 1
naver_closig_price = (474500, 461500, 501000, 500500, 488500)
naver_closig_price
# Out:
# (474500, 461500, 501000, 500500, 488500)

# %%
# 2
print(max(naver_closig_price))
# Out:
# 501000

# %%
# 3
print(min(naver_closig_price))
# Out:
# 461500

# %%
# 4
gap = max(naver_closig_price) - min(naver_closig_price)
print(gap)
# Out:
# 39500

# %%
# 5
print(naver_closig_price[2])
# Out:
# 501000

# %%
# 6
naver_closig_price2 = {"0907": 474500, "0908": 461500, "0909": 501000, "0910": 500500, "0911": 488500}
naver_closig_price2
# Out:
# {'0907': 474500,
#  '0908': 461500,
#  '0909': 501000,
#  '0910': 500500,
#  '0911': 488500}

# %%
# 6
print(naver_closig_price2["0909"])
# Out:
# 501000
