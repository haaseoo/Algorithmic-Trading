# %%
mystring = 'hello world'
mystring1 = 'a'
mystring2 = "a"
mystring3 = "abc mart"

# %%
mystring
# Out:
# 'hello world'

# %%
print(mystring)
# Out:
# hello world

# %%
len(mystring)
# Out:
# 11

# %%
mystring[0:5]
# Out:
# 'hello'

# %%
mystring[6:11]
# Out:
# 'world'

# %%
mystring[6:]
# Out:
# 'world'

# %%
mystring[:5]
# Out:
# 'hello'

# %%
mystring[6:-1]
# Out:
# 'worl'

# %%
my_jusik = "naver daum"

# %%
my_jusik
# Out:
# 'naver daum'

# %%
my_jusik.split(' ')
# Out:
# ['naver', 'daum']

# %%
my_jusik.split(' ')[0]
# Out:
# 'naver'

# %%
print(my_jusik.split(' ')[0])
# Out:
# naver

# %%
split_jusik = my_jusik.split(' ')
split_jusik
# Out:
# ['naver', 'daum']

# %%
print(split_jusik[0])
# Out:
# naver

# %%
daum = "Daum"
kakao = "KAKAO"

# %%
daum + kakao
# Out:
# 'DaumKAKAO'

# %%
daum + ' ' + kakao
# Out:
# 'Daum KAKAO'
