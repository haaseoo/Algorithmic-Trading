# %%
f = open('/Users/anhaseo/Desktop/py/Algorithmic-Trading/unit7/buy_list.txt', 'rt')

# %%
lines = f.readlines()
lines
# Out:
# ['META\n', 'AMD\n', 'UNH']

# %%
for line in lines:
  print(line)
# Out:
# META
#
# AMD
#
# UNH

# %%
for line in lines:
  print(line, end='')
# Out:
# META
# AMD
# UNH

# %%
for line in lines:
  nline = line.split('\n')[0]
  print(nline)
# Out:
# META
# AMD
# UNH
